# %%
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.seattle.gov", None)

# Example authenticated client (needed for non-public datasets):
#client = Socrata(data.seattle.gov,
                  #MyAppToken,
                  #userame="user@example.com",
                  #password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("tmmm-ytt6", checkoutyear = 2019, limit = 10000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9ebb0c99a594> in <module>
#      11 # First 2000 results, returned as JSON from API / converted to Python list of
#      12 # dictionaries by sodapy.
# ---> 13 results = client.get("tmmm-ytt6", checkoutyear > 2014, limit = 10000000)
#      14
#      15 # Convert to pandas DataFrame
#
# NameError: name 'checkoutyear' is not defined

# %%
results_df.to_csv('2019Checkouts.csv', index=False)

# %%
y2018 = client.get("tmmm-ytt6", checkoutyear = 2018, limit = 10000000)
# Out:
# [{'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2018',
#   'checkoutmonth': '12',
#   'checkouts': '1',
#   'title': 'Naruto. Vol. 65, Hashirama and Madara / story and art by Masashi Kishimoto ; translation, Mari Morimoto.',
#   'creator': 'Kishimoto, Masashi, 1974-',
#   'subjects': 'Naruto Fictitious character Comic books strips etc, Ninja Japan Comic books strips etc, Graphic novels',
#   'publisher': 'VIZ Media,',
#   'publicationyear': '[2014]'},
#  {'usageclass': 'Physical',
#   'checkouttype': 'Horizon',
#   'materialtype': 'BOOK',
#   'checkoutyear': '2018',
#   'checkoutmonth': '12',
#   'checkouts': '2',
#   'title': 'Oishisō na shirokuma / Shibata Keiko.',
#   'creator': 'Shibata, Keiko.',
#   'subjects': 'Polar bear Juvenile fiction, Food Juvenile fiction, Picture books for children, Japanese language materials',
#   'publisher': 'Pīeichipīkenkyūjo,',
#   'publicationyear': '2017.'},
# ...

# %%
results_df = pd.DataFrame.from_records(y2018)
results_df
# Out:
#         checkoutmonth checkouts checkouttype checkoutyear  \
# 0                  12         1      Horizon         2018
# 1                  12         2      Horizon         2018
# 2                  12         7      Horizon         2018
# 3                  12         3    OverDrive         2018
# 4                  12         1      Horizon         2018
# 5                  12         1      Horizon         2018
# 6                  12         2      Horizon         2018
# 7                  12         6    OverDrive         2018
# 8                  12         8      Horizon         2018
# 9                  12         4      Horizon         2018
# 10                 12        11      Horizon         2018
# 11                 12         1      Horizon         2018
# 12                 12         4      Horizon         2018
# 13                 12         1      Horizon         2018
# 14                 12         1      Horizon         2018
# ...

# %%
results_df.to_csv('2018Checkouts.csv', index = False)

# %%
y2017 = client.get("tmmm-ytt6", checkoutyear = 2017, limit = 10000000)
results_df = pd.DataFrame.from_records(y2017)
results_df
# Out:
#         checkoutmonth checkouts checkouttype checkoutyear  \
# 0                  12         1      Horizon         2017
# 1                  12         6    OverDrive         2017
# 2                  12         2      Horizon         2017
# 3                  12         3    OverDrive         2017
# 4                  12         2    OverDrive         2017
# 5                  12         1    OverDrive         2017
# 6                  12         2    OverDrive         2017
# 7                  12         1    OverDrive         2017
# 8                  12         1      Horizon         2017
# 9                  12         1      Freegal         2017
# 10                 12         5    OverDrive         2017
# 11                 12         5      Horizon         2017
# 12                 12         1      Freegal         2017
# 13                 12         5      Horizon         2017
# 14                 12         2      Horizon         2017
# ...

# %%
results_df.to_csv('2017Checkouts.csv')

# %%
y2016 = client.get("tmmm-ytt6", checkoutyear = 2016, limit = 10000000)
results_df = pd.DataFrame.from_records(y2016)
results_df
# Out:
#         checkoutmonth checkouts checkouttype checkoutyear  \
# 0                  10         1    OverDrive         2016
# 1                  10         7      Horizon         2016
# 2                  10         1    OverDrive         2016
# 3                  10         1      Horizon         2016
# 4                  10         3      Horizon         2016
# 5                  10         1      Horizon         2016
# 6                  10        12      Horizon         2016
# 7                  10         2      Horizon         2016
# 8                  10         8      Horizon         2016
# 9                  10         3      Horizon         2016
# 10                 10         1    OverDrive         2016
# 11                 10         3      Horizon         2016
# 12                 10         1      Horizon         2016
# 13                 10         1      Freegal         2016
# 14                 10         3      Horizon         2016
# ...

# %%
results_df.to_csv('2016Checkouts.csv')

# %%
y2015 = client.get("tmmm-ytt6", checkoutyear = 2015, limit = 10000000)
results_df = pd.DataFrame.from_records(y2015)
results_df.to_csv('2015Checkouts.csv')

# %%
y2014 = client.get("tmmm-ytt6", checkoutyear = 2014, limit = 10000000)
results_df = pd.DataFrame.from_records(y2014)
results_df.to_csv('2014Checkouts.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-9abc29be4b8d> in <module>
#       1 y2014 = client.get("tmmm-ytt6", checkoutyear = 2014, limit = 10000000)
#       2 results_df = pd.DataFrame.from_records(y2014)
# ----> 3 results_df.to_csv('2014Checkouts.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ...
